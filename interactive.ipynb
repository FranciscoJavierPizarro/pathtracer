# %%
import matplotlib.pyplot as plt
import time

from geometry import Camera, Scene, Sphere, Plane, Light
from raytracer import RayTracer
from Tone_map import ecualization_inv, gammaFunc


def create_cornell_box():
    """Crear una escena estilo Cornell Box."""
    scene = Scene()
    scene.add_light(Light([0.0, 1.8, -1.0], intensity=1.2))

    scene.add_sphere(Sphere([-0.3, -0.2, -0.8], 0.3, [0.9, 0.9, 0.9], material=[1, 0, 0]))
    scene.add_sphere(Sphere([0.9, -0.3, -1.2], 0.2, [0.8, 0.2, 0.2], material=[0, 1, 0], ior=0.7))
    scene.add_sphere(Sphere([0.0, 0.2, -1.5], 0.4, [0.2, 0.8, 0.5], material=[0, 0, 1], ior=1.5))

    scene.add_plane(Plane([0, -0.5, 0], [0, 1, 0], [0.9, 0.9, 0.9]))     # suelo
    scene.add_plane(Plane([0, 2.0, 0], [0, -1, 0], [0.9, 0.9, 0.9]))     # techo
    scene.add_plane(Plane([-1.5, 0, 0], [1, 0, 0], [0.4, 0.2, 0.2]))     # pared roja
    scene.add_plane(Plane([1.5, 0, 0], [-1, 0, 0], [0.2, 0.8, 0.5]))     # pared verde
    scene.add_plane(Plane([0, 0, -2.5], [0, 0, 1], [0.9, 0.9, 0.9]))     # fondo
    return scene


def configure_camera(width, height):
    """Devuelve una cámara adecuada según la escena."""
    aspect_ratio = width / height
    return Camera(
            fov_deg=60,
            aspect_ratio=aspect_ratio,
            lookfrom=(0, 0.5, 1.5),
            lookat=(0, 0, -1),
            vup=(0, 1, 0)
        )


def display_image(image, title="Ray Tracing", save_path=None):
    """Mostrar la imagen renderizada y opcionalmente guardarla."""
    plt.figure(figsize=(12, 8))
    plt.imshow(image)
    plt.axis('off')
    plt.title(title)
    plt.tight_layout()
    if save_path:
        plt.savefig(save_path, dpi=300, bbox_inches='tight')
        print(f"✅ Imagen guardada en: {save_path}")
    plt.show()


def run_render(width, height, 
               use_gpu=True, samples=1, bounces=2, save_path=None):
    """Ejecuta el render de forma interactiva (profiling-ready)."""
    print(f"Resolución: {width}x{height} | {'GPU' if use_gpu else 'CPU'}")

    scene = create_cornell_box()

    camera = configure_camera(width, height)

    tracer = RayTracer(width=width, height=height, prefer_gpu=use_gpu, samples=samples, bounces=bounces)
    tracer.set_camera(camera)

    start = time.time()
    image = tracer.render(scene)
    end = time.time()

    print(f"✅ Render completado en {end - start:.2f} segundos")

    image = gammaFunc(1, 1.2, image)  # Aplicar corrección gamma

    display_image(image, "" , save_path)
    return image, end - start

display_image(run_render(width=1920, height=1080, use_gpu=True, samples=500, bounces=20)[0],
              title="Cornell Box - GPU Render", save_path="cornell_box_gpu.png")
# Out:
# Resolución: 1920x1080 | GPU
# Ray Tracer: 1920x1080, usando GPU
# Renderizando en GPU (Optimizado): 1920x1080, 100 SPP, 40 rebotes
# Error en renderizado: Failed in cuda mode pipeline (step: nopython frontend)
# Untyped global name 'local': Cannot determine Numba type of <class 'type'>
#
# File "gpu_renderer.py", line 321:
#     def render_kernel_optimized(image, width, height,
#         <source elided>
#         # Estado RNG local
#         rng_state = local.array(1, types.uint32)
#         ^
#
# During: Pass nopython_type_inference
# Intentando fallback a CPU...
# /home/jorges/Escritorio/Prog/Grafica/cpu_renderer.py:15: RuntimeWarning: invalid value encountered in divide
#   return v / fast_norm(v)
# ---------------------------------------------------------------------------
# TypingError                               Traceback (most recent call last)
# File ~/Escritorio/Prog/Grafica/raytracer.py:53, in RayTracer.render(self, scene)
#      52 if self.use_gpu:
# ---> 53     return self.gpu_renderer.render(scene, self.camera, self.width, self.height)
#      54 else:
#
# File ~/Escritorio/Prog/Grafica/gpu_renderer.py:413, in GPURenderer.render(self, scene, camera, width, height)
#     411 start_time = time.time()
# --> 413 render_kernel_optimized[blocks_per_grid, threads_per_block](
#     414     image, width, height,
#     415     camera.origin, camera.lower_left_corner, camera.horizontal, camera.vertical,
#     416     light_position,
#     417     sphere_data, sphere_colors, sphere_materials, len(scene.spheres),
#     418     plane_data, plane_colors, plane_materials, len(scene.planes),
#     419     self.samples_per_pixel, self.max_bounces
#     420 )
#     422 cuda.synchronize()
#
# File ~/Escritorio/Prog/grenv/lib/python3.12/site-packages/numba/cuda/dispatcher.py:539, in _LaunchConfiguration.__call__(self, *args)
#     538 def __call__(self, *args):
# --> 539     return self.dispatcher.call(args, self.griddim, self.blockdim,
#     540                                 self.stream, self.sharedmem)
#
# File ~/Escritorio/Prog/grenv/lib/python3.12/site-packages/numba/cuda/dispatcher.py:681, in CUDADispatcher.call(self, args, griddim, blockdim, stream, sharedmem)
#     680 else:
# --> 681     kernel = _dispatcher.Dispatcher._cuda_call(self, *args)
#     683 kernel.launch(args, griddim, blockdim, stream, sharedmem)
#
# File ~/Escritorio/Prog/grenv/lib/python3.12/site-packages/numba/cuda/dispatcher.py:689, in CUDADispatcher._compile_for_args(self, *args, **kws)
#     688 argtypes = [self.typeof_pyval(a) for a in args]
# --> 689 return self.compile(tuple(argtypes))
#
# File ~/Escritorio/Prog/grenv/lib/python3.12/site-packages/numba/cuda/dispatcher.py:932, in CUDADispatcher.compile(self, sig)
#     930     raise RuntimeError("Compilation disabled")
# --> 932 kernel = _Kernel(self.py_func, argtypes, **self.targetoptions)
#     933 # We call bind to force codegen, so that there is a cubin to cache
#
# File ~/Escritorio/Prog/grenv/lib/python3.12/site-packages/numba/core/compiler_lock.py:35, in _CompilerLock.__call__.<locals>._acquire_compile_lock(*args, **kwargs)
#      34 with self:
# ---> 35     return func(*args, **kwargs)
#
# File ~/Escritorio/Prog/grenv/lib/python3.12/site-packages/numba/cuda/dispatcher.py:83, in _Kernel.__init__(self, py_func, argtypes, link, debug, lineinfo, inline, fastmath, extensions, max_registers, opt, device)
#      82 cc = get_current_device().compute_capability
# ---> 83 cres = compile_cuda(self.py_func, types.void, self.argtypes,
#      84                     debug=self.debug,
#      85                     lineinfo=lineinfo,
#      86                     inline=inline,
#      87                     fastmath=fastmath,
#      88                     nvvm_options=nvvm_options,
#      89                     cc=cc)
#      90 tgt_ctx = cres.target_context
#
# File ~/Escritorio/Prog/grenv/lib/python3.12/site-packages/numba/core/compiler_lock.py:35, in _CompilerLock.__call__.<locals>._acquire_compile_lock(*args, **kwargs)
#      34 with self:
# ---> 35     return func(*args, **kwargs)
#
# File ~/Escritorio/Prog/grenv/lib/python3.12/site-packages/numba/cuda/compiler.py:196, in compile_cuda(pyfunc, return_type, args, debug, lineinfo, inline, fastmath, nvvm_options, cc)
#     195 with target_override('cuda'):
# --> 196     cres = compiler.compile_extra(typingctx=typingctx,
#     197                                   targetctx=targetctx,
#     198                                   func=pyfunc,
#     199                                   args=args,
#     200                                   return_type=return_type,
#     201                                   flags=flags,
#     202                                   locals={},
#     203                                   pipeline_class=CUDACompiler)
#     205 library = cres.library
#
# File ~/Escritorio/Prog/grenv/lib/python3.12/site-packages/numba/core/compiler.py:739, in compile_extra(typingctx, targetctx, func, args, return_type, flags, locals, library, pipeline_class)
#     737 pipeline = pipeline_class(typingctx, targetctx, library,
#     738                           args, return_type, flags, locals)
# --> 739 return pipeline.compile_extra(func)
#
# File ~/Escritorio/Prog/grenv/lib/python3.12/site-packages/numba/core/compiler.py:439, in CompilerBase.compile_extra(self, func)
#     438 self.state.lifted_from = None
# --> 439 return self._compile_bytecode()
#
# File ~/Escritorio/Prog/grenv/lib/python3.12/site-packages/numba/core/compiler.py:505, in CompilerBase._compile_bytecode(self)
#     504 assert self.state.func_ir is None
# --> 505 return self._compile_core()
#
# File ~/Escritorio/Prog/grenv/lib/python3.12/site-packages/numba/core/compiler.py:484, in CompilerBase._compile_core(self)
#     483         if is_final_pipeline:
# --> 484             raise e
#     485 else:
#
# File ~/Escritorio/Prog/grenv/lib/python3.12/site-packages/numba/core/compiler.py:473, in CompilerBase._compile_core(self)
#     472 try:
# --> 473     pm.run(self.state)
#     474     if self.state.cr is not None:
#
# File ~/Escritorio/Prog/grenv/lib/python3.12/site-packages/numba/core/compiler_machinery.py:367, in PassManager.run(self, state)
#     366 patched_exception = self._patch_error(msg, e)
# --> 367 raise patched_exception
#
# File ~/Escritorio/Prog/grenv/lib/python3.12/site-packages/numba/core/compiler_machinery.py:356, in PassManager.run(self, state)
#     355 if isinstance(pass_inst, CompilerPass):
# --> 356     self._runPass(idx, pass_inst, state)
#     357 else:
#
# File ~/Escritorio/Prog/grenv/lib/python3.12/site-packages/numba/core/compiler_lock.py:35, in _CompilerLock.__call__.<locals>._acquire_compile_lock(*args, **kwargs)
#      34 with self:
# ---> 35     return func(*args, **kwargs)
#
# File ~/Escritorio/Prog/grenv/lib/python3.12/site-packages/numba/core/compiler_machinery.py:311, in PassManager._runPass(self, index, pss, internal_state)
#     310 with SimpleTimer() as pass_time:
# --> 311     mutated |= check(pss.run_pass, internal_state)
#     312 with SimpleTimer() as finalize_time:
#
# File ~/Escritorio/Prog/grenv/lib/python3.12/site-packages/numba/core/compiler_machinery.py:272, in PassManager._runPass.<locals>.check(func, compiler_state)
#     271 def check(func, compiler_state):
# --> 272     mangled = func(compiler_state)
#     273     if mangled not in (True, False):
#
# File ~/Escritorio/Prog/grenv/lib/python3.12/site-packages/numba/core/typed_passes.py:112, in BaseTypeInference.run_pass(self, state)
#     109 with fallback_context(state, 'Function "%s" failed type inference'
#     110                       % (state.func_id.func_name,)):
#     111     # Type inference
# --> 112     typemap, return_type, calltypes, errs = type_inference_stage(
#     113         state.typingctx,
#     114         state.targetctx,
#     115         state.func_ir,
#     116         state.args,
#     117         state.return_type,
#     118         state.locals,
#     119         raise_errors=self._raise_errors)
#     120     state.typemap = typemap
#
# File ~/Escritorio/Prog/grenv/lib/python3.12/site-packages/numba/core/typed_passes.py:91, in type_inference_stage(typingctx, targetctx, interp, args, return_type, locals, raise_errors)
#      89     infer.seed_type(k, v)
# ---> 91 infer.build_constraint()
#      92 # return errors in case of partial typing
#
# File ~/Escritorio/Prog/grenv/lib/python3.12/site-packages/numba/core/typeinfer.py:1027, in TypeInferer.build_constraint(self)
#    1026 for inst in blk.body:
# -> 1027     self.constrain_statement(inst)
#
# File ~/Escritorio/Prog/grenv/lib/python3.12/site-packages/numba/core/typeinfer.py:1389, in TypeInferer.constrain_statement(self, inst)
#    1388 if isinstance(inst, ir.Assign):
# -> 1389     self.typeof_assign(inst)
#    1390 elif isinstance(inst, ir.SetItem):
#
# File ~/Escritorio/Prog/grenv/lib/python3.12/site-packages/numba/core/typeinfer.py:1464, in TypeInferer.typeof_assign(self, inst)
#    1463 elif isinstance(value, (ir.Global, ir.FreeVar)):
# -> 1464     self.typeof_global(inst, inst.target, value)
#    1465 elif isinstance(value, ir.Arg):
#
# File ~/Escritorio/Prog/grenv/lib/python3.12/site-packages/numba/core/typeinfer.py:1564, in TypeInferer.typeof_global(self, inst, target, gvar)
#    1563 try:
# -> 1564     typ = self.resolve_value_type(inst, gvar.value)
#    1565 except TypingError as e:
#
# File ~/Escritorio/Prog/grenv/lib/python3.12/site-packages/numba/core/typeinfer.py:1485, in TypeInferer.resolve_value_type(self, inst, val)
#    1484     msg = str(e)
# -> 1485 raise TypingError(msg, loc=inst.loc)
#
# TypingError: Failed in cuda mode pipeline (step: nopython frontend)
# Untyped global name 'local': Cannot determine Numba type of <class 'type'>
#
# File "gpu_renderer.py", line 321:
#     def render_kernel_optimized(image, width, height,
#         <source elided>
#         # Estado RNG local
#         rng_state = local.array(1, types.uint32)
#         ^
#
# During: Pass nopython_type_inference
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 74
#      71     display_image(image, "" , save_path)
#      72     return image, end - start
# ---> 74 display_image(run_render(width=1920, height=1080, use_gpu=True, samples=100, bounces=40)[0],
#      75               title="Cornell Box - GPU Render", save_path="cornell_box_gpu.png")
#
# Cell In[1], line 64, in run_render(width, height, use_gpu, samples, bounces, save_path)
#      61 tracer.set_camera(camera)
#      63 start = time.time()
# ---> 64 image = tracer.render(scene)
#      65 end = time.time()
#      67 print(f"✅ Render completado en {end - start:.2f} segundos")
#
# File ~/Escritorio/Prog/Grafica/raytracer.py:61, in RayTracer.render(self, scene)
#      59     print("Intentando fallback a CPU...")
#      60     self.use_gpu = False
# ---> 61     return self.cpu_renderer.render(scene, self.camera, self.width, self.height)
#      62 else:
#      63     raise
#
# File ~/Escritorio/Prog/Grafica/cpu_renderer.py:216, in CPURenderer.render(self, scene, camera, width, height)
#     208     ray_dir = (
#     209         camera.lower_left_corner +
#     210         u * camera.horizontal +
#     211         v * camera.vertical -
#     212         camera.origin
#     213     )
#     214     ray_dir = normalize(ray_dir)
# --> 216     pixel_color += trace_ray(
#     217         camera.origin, ray_dir,
#     218         scene.spheres, scene.planes, light_pos,
#     219         depth=0, max_depth=self.max_bounces
#     220     )
#     222 pixel_color /= self.samples_per_pixel
#     223 image[y, x] = pixel_color
#
# File ~/Escritorio/Prog/Grafica/cpu_renderer.py:181, in trace_ray(origin, direction, spheres, planes, light_pos, depth, max_depth)
#     178 chosen_type_idx = np.random.choice(3, p=probs)
#     180 if chosen_type_idx == 0:  # Difuso
# --> 181     final_color += shade_diffuse(hit_point, hit_normal, hit_color, spheres, planes, light_pos, depth, max_depth)
#     182 elif chosen_type_idx == 1:  # Espejo
#     183     final_color += shade_mirror(direction, hit_point, hit_normal, spheres, planes, light_pos, depth, max_depth)
#
# File ~/Escritorio/Prog/Grafica/cpu_renderer.py:101, in shade_diffuse(hit_point, hit_normal, hit_color, spheres, planes, light_pos, depth, max_depth)
#     100 def shade_diffuse(hit_point, hit_normal, hit_color, spheres, planes, light_pos, depth, max_depth) -> np.ndarray:
# --> 101     bounce_dir = cosine_weighted_hemisphere_sample(hit_normal)
#     102     bias_point = hit_point + hit_normal * 0.001
#     103     bounced_color = trace_ray(bias_point, bounce_dir, spheres, planes, light_pos, depth + 1, max_depth)
#
# File ~/Escritorio/Prog/Grafica/cpu_renderer.py:76, in cosine_weighted_hemisphere_sample(normal)
#      73     up = np.array([1.0, 0.0, 0.0], dtype=np.float32)
#      75 tangent = normalize(np.cross(normal, up))
# ---> 76 bitangent = np.cross(normal, tangent)
#      78 world_dir = local_dir[0] * tangent + local_dir[1] * bitangent + local_dir[2] * normal
#      79 return normalize(world_dir)
#
# File ~/Escritorio/Prog/grenv/lib/python3.12/site-packages/numpy/_core/numeric.py:1518, in _cross_dispatcher(a, b, axisa, axisb, axisc, axis)
#    1514     result = transpose(order)
#    1515     return result
# -> 1518 def _cross_dispatcher(a, b, axisa=None, axisb=None, axisc=None, axis=None):
#    1519     return (a, b)
#    1522 @array_function_dispatch(_cross_dispatcher)
#    1523 def cross(a, b, axisa=-1, axisb=-1, axisc=-1, axis=None):
#
# KeyboardInterrupt:
